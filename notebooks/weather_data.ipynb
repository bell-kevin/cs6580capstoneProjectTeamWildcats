# %% [markdown]
# ## Load Weather Data into DFs

# %%
import pandas as pd

df_2016 = pd.read_excel("../data/raw/weatherData/SBBWK_2016.xlsx")
df_2017 = pd.read_excel("../data/raw/weatherData/SBBWK_2017.xlsx")
df_2018 = pd.read_excel("../data/raw/weatherData/SBBWK_2018.xlsx")
df_2019 = pd.read_excel("../data/raw/weatherData/SBBWK_2019.xlsx")
df_2020 = pd.read_excel("../data/raw/weatherData/SBBWK_2020.xlsx")
df_2021 = pd.read_excel("../data/raw/weatherData/SBBWK_2021.xlsx")
df_2022 = pd.read_excel("../data/raw/weatherData/SBBWK_2022.xlsx")
df_2023 = pd.read_excel("../data/raw/weatherData/SBBWK_2023.xlsx")
df_2024 = pd.read_excel("../data/raw/weatherData/SBBWK_2024.xlsx")
df_2025 = pd.read_excel("../data/raw/weatherData/SBBWK_2025.xlsx")
df_2026 = pd.read_excel("../data/raw/weatherData/SBBWK_2026.xlsx")

df = pd.concat([
    df_2016,  
    df_2017,
    df_2018,
    df_2019,
    df_2020,
    df_2021,
    df_2022,
    df_2023,
    df_2024,
    df_2025,
    df_2026
])

df.to_csv("../data/processed/weatherData/weather_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       8 df_2021 = pd.read_excel("../data/raw/weatherData/SBBWK_2021.xlsx")
#       9 df_2022 = pd.read_excel("../data/raw/weatherData/SBBWK_2022.xlsx")
# ---> 10 df_2023 = pd.read_excel("../data/raw/weatherData/SBBWK_2023.xlsx")
#      11 df_2024 = pd.read_excel("../data/raw/weatherData/SBBWK_2024.xlsx")
#      12 df_2025 = pd.read_excel("../data/raw/weatherData/SBBWK_2025.xlsx")
#
# File c:\Users\danir\miniconda3\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
# ...
